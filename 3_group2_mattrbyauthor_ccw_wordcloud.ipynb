# %% [markdown]
# <a href="https://colab.research.google.com/github/ms624atyale/PictureBook_Project_Demo/blob/main/3_group2_mattrbyauthor_ccw_wordcloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐹🐾 <font color = 'green'>>**Converting compiled .txt to csv:** <font color = 'pink'>_This stage can be skipped if you have already done it_.

# %%
# !pip install pandas
# !pip install lexical_diversity
import pandas as pd #Import Pandas Package
import lexical_diversity as ld
import glob

#Cloning your repository and set up your current working directory 🍎🍎🍎🍎🍎
#!git clone https://github.com/ms624atyale/PictureBook_Project_Demo
# %cd /content/PictureBook_Project_Demo/Data_Frame_Group2

# Load all .txt files of your current working directory
fns = glob.glob('*.txt')

# List to hold each temporary DataFrame
df_list = []

# Load each file and append to list
for fn in fns:
    dftmp = pd.read_csv(fn, sep='@')
    df_list.append(dftmp)

# Concatenate all and reset index
df = pd.concat(df_list, ignore_index=True)

# Save as CSV 🍎🍎🍎🍎🍎
df.to_csv("./2creators_2books.csv", index=False)

# Display the DataFrame
print(df)
df
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: lexical_diversity in /usr/local/lib/python3.11/dist-packages (0.1.1)
# /content/PictureBook_Project_Demo/Data_Frame_Group2
#                                                 text  \
# 0  the wind blew hard and joggled the water of th...
# 1  the cyclone   dorothy lived in the midst of th...
# 2  far out in the wide sea where the water is blu...
# 3  it was beautiful in the country it was summer-...
#
#                         title                  creator
# 0                  ozma of oz         lyman frank baum
# 1  the wonderful wizard of oz         lyman frank baum
# 2          the little mermaid  hans christian andersen
# 3           the ugly duckling  hans christian andersen
#                                                 text  \
# 0  the wind blew hard and joggled the water of th...
# 1  the cyclone   dorothy lived in the midst of th...
# 2  far out in the wide sea where the water is blu...
# 3  it was beautiful in the country it was summer-...
#
#                         title                  creator
# 0                  ozma of oz         lyman frank baum
# 1  the wonderful wizard of oz         lyman frank baum
# 2          the little mermaid  hans christian andersen
# 3           the ugly duckling  hans christian andersen

# %%
import pandas as pd
from lexical_diversity import lex_div as ld

# Load the CSV (skip if already loaded) 🍎🍎🍎🍎🍎
df = pd.read_csv("./2creators_2books.csv", sep=",")

# %% [markdown]
# # <font color = 'blue'> **Getting TTR and MATTR** (based on N_tokens and N_lemmas) including ['Data Size] using len( )

# %%
# !pip install textstat
import textstat

# Added column: String length for estimating data size
length = []

for i in range(0, len(df['text'])):
  LEN = len(df['text'][i])
  length.append(LEN)

df['Data size'] = length


# Added columns:  Number of Splitted words & Length of splitted words
tsplit = []
splen = []

for i in range(0, len(df['text'])):
  TSP = df['text'][i].split()
  SPLEN = len(TSP)
  tsplit.append(TSP)
  splen.append(SPLEN)

df['Splits'] = tsplit
df['N_Splits'] = splen

# Added column: Lemma 표제어
#df['Lemma'] is a column from a pandas DataFrame, so len(df['Lemma']) gives you the number of rows (or entries) in that column.
lemma = []

for i in range(0, len(df['text'])):
  LEM = ld.flemmatize(df['text'][i])
  print(LEM)
  lemma.append(LEM)

df['Lemma'] = lemma


# ADD Lexical Diversity indices

#1. Create two empty lists--one for Type to Token Ratio and the other Moving Average Type to Token Ratio.
TTR = []
MATTR = []

#2. Getting LD index values for each cell:

for i in range(0, len(df['Lemma'])):
  flt = df['Lemma'][i]
  ttr = ld.ttr(flt)
  mattr = ld.mattr(flt)

  #2-1. Add values to each list
  TTR.append(ttr)
  MATTR.append(mattr)


#3. Add columns for TTR and MATTR
df['TTR'] = TTR
df['MATTR'] = MATTR

print(df)
df_selected = df[['creator','N_Splits','MATTR']]
df_selected
# Out:
# Collecting textstat
#   Downloading textstat-0.7.7-py3-none-any.whl.metadata (15 kB)
# Collecting pyphen (from textstat)
#   Downloading pyphen-0.17.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting cmudict (from textstat)
#   Downloading cmudict-1.0.32-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from textstat) (75.2.0)
# Requirement already satisfied: importlib-metadata>=5 in /usr/local/lib/python3.11/dist-packages (from cmudict->textstat) (8.7.0)
# Requirement already satisfied: importlib-resources>=5 in /usr/local/lib/python3.11/dist-packages (from cmudict->textstat) (6.5.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=5->cmudict->textstat) (3.22.0)
# Downloading textstat-0.7.7-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 3.4 MB/s eta 0:00:00
# Downloading cmudict-1.0.32-py3-none-any.whl (939 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 939.4/939.4 kB 19.0 MB/s eta 0:00:00
# Downloading pyphen-0.17.2-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 48.2 MB/s eta 0:00:00
# Installing collected packages: pyphen, cmudict, textstat
# Successfully installed cmudict-1.0.32 pyphen-0.17.2 textstat-0.7.7
# ['the', 'wind', 'blow', 'hard', 'and', 'joggle', 'the', 'water', 'of', 'the', 'ocean', 'send', 'ripple', 'across', 'its', 'surface', 'then', 'the', 'wind', 'push', 'the', 'edge', 'of', 'the', 'ripple', 'until', 'they', 'become', 'wave', 'and', 'shove', 'the', 'wave', 'around', 'until', 'they', 'become', 'billow', 'the', 'billow', 'roll', 'dreadfully', 'high', 'high', 'even', 'than', 'the', 'top', 'of', 'house', 'some', 'of', 'them', 'indeed', 'roll', 'as', 'high', 'as', 'the', 'top', 'of', 'tall', 'tree', 'and', 'seem', 'like', 'mountain', 'and', 'the', 'gulf', 'between', 'the', 'great', 'billow', 'be', 'like', 'deep', 'valley', 'all', 'this', 'mad', 'dash', 'and', 'splash', 'of', 'the', 'water', 'of', 'the', 'big', 'ocean', 'which', 'the', 'mischievous', 'wind', 'cause', 'without', 'any', 'good', 'reason', 'whatever', 'result', 'in', 'a', 'terrible', 'storm', 'and', 'a', 'storm', 'on', 'the', 'ocean', 'be', 'liable', 'to', 'cut', 'many', 'queer', 'prank', 'and', 'do', 'a', 'lot', 'of', 'damage', 'at', 'the', 'time', 'the', 'wind', 'begin', 'to', 'blow', 'a', 'ship', 'be', 'sailing', 'far', 'out', 'upon', 'the', 'water', 'when', 'the', 'wave', 'begin', 'to', 'tumble', 'and', 'toss', 'and', 'to', 'grow', 'big', 'and', 'big', 'the', 'ship', 'roll', 'up', 'and', 'down', 'and', 'tip', 'sidewise', 'first', 'one', 'way', 'and', 'then', 'the', 'other', 'and', 'be', 'jostle', 'around', 'so', 'roughly', 'that', 'even', 'the', 'sailormen', 'have', 'to', 'hold', 'fast', 'to', 'the', 'rope', 'and', 'railing', 'to', 'keep', 'themselves', 'from', 'being', 'sweep', 'away', 'by', 'the', 'wind', 'or', 'pitch', 'headlong', 'into', 'the', 'sea', 'and', 'the', 'cloud', 'be', 'so', 'thick', 'in', 'the', 'sky', 'that', 'the', 'sunlight', 'couldnt', 'get', 'through', 'them', 'so', 'that', 'the', 'day', 'grow', 'dark', 'as', 'night', 'which', 'add', 'to', 'the', 'terror', 'of', 'the', 'storm', 'the', 'captain', 'of', 'the', 'ship', 'be', 'not', 'afraid', 'because', 'he', 'have', 'see', 'storm', 'before', 'and', 'have', 'sail', 'his', 'ship', 'through', 'them', 'in', 'safety', 'but', 'he', 'know', 'that', 'his', 'passenger', 'would', 'be', 'in', 'danger', 'if', 
chick', 'all', 'the', 'egg', 'be', 'alive', 'and', 'one', 'little', 'head', 'after', 'another', 'appear', 'quack', 'quack', 'say', 'the', 'duck', 'and', 'all', 'get', 'up', 'as', 'well', 'as', 'they', 'could', 'they', 'peep', 'about', 'from', 'under', 'the', 'green', 'leave', 'and', 'as', 'green', 'be', 'good', 'for', 'the', 'eye', 'their', 'mother', 'let', 'them', 'look', 'as', 'long', 'as', 'they', 'please', 'how', 'large', 'the', 'world', 'be', 'say', 'the', 'little', 'one', 'for', 'they', 'found', 'their', 'present', 'situation', 'very', 'different', 'to', 'their', 'former', 'confine', 'one', 'while', 'yet', 'in', 'the', 'eggshell', 'do', 'you', 'imagine', 'this', 'to', 'be', 'the', 'whole', 'of', 'the', 'world', 'say', 'the', 'mother', 'it', 'extend', 'far', 'beyond', 'the', 'other', 'side', 'of', 'the', 'garden', 'to', 'the', 'pastor', 's', 'field', 'but', 'i', 'have', 'never', 'be', 'there', 'be', 'you', 'all', 'here', 'and', 'then', 'she', 'get', 'up', 'no', 'i', 'have', 'not', 'get', 'you', 'all', 'the', 'large', 'egg', 'be', 'still', 'here', 'how', 'long', 'will', 'this', 'last', 'i', 'be', 'so', 'weary', 'of', 'it', 'and', 'then', 'she', 'sit', 'down', 'again', 'well', 'and', 'how', 'be', 'you', 'get', 'on', 'ask', 'a', 'old', 'duck', 'who', 'have', 'come', 'to', 'pay', 'her', 'a', 'visit', 'this', 'one', 'egg', 'keep', 'me', 'so', 'long', 'say', 'the', 'mother', 'it', 'will', 'not', 'break', 'but', 'you', 'should', 'see', 'the', 'other', 'they', 'be', 'the', 'pretty', 'little', 'duckling', 'i', 'have', 'see', 'in', 'all', 'my', 'day', 'they', 'be', 'all', 'like', 'their', 'father', 'the', 'goodfornothing', 'fellow', 'he', 'have', 'not', 'be', 'to', 'visit', 'me', 'once', 'let', 'me', 'see', 'the', 'egg', 'that', 'will', 'not', 'break', 'say', 'the', 'old', 'duck', 'depend', 'upon', 'it', 'it', 'be', 'a', 'turkey', 's', 'egg', 'i', 'be', 'cheat', 'in', 'the', 'same', 'way', 'once', 'myself', 'and', 'i', 'have', 'such', 'trouble', 'with', 'the', 'young', 'one', 'for', 'they', 'be', 'afraid', 'of', 'the', 'water', 'and', 'i', 'could', 'not', 'get', 'them', 'there', 'i', 'call', 'and', 'scold', 'but', 'it', 'be', 'all', 'of', 'no', 'use', 'but', 'let', 'me', 'see', 'the', 'egg', 'ah', 'yes', 'to', 'be', 'sure', 'that', 'be', 'a', 'turkey', 's', 'egg', 'leave', 'it', 'and', 'teach', 'the', 'other', 'little', 'one', 'to', 'swim', 'i', 'will', 'sit', 'on', 'it', 'a' ...
#                                                 text  \
# 0  the wind blew hard and joggled the water of th...
# 1  the cyclone   dorothy lived in the midst of th...
# 2  far out in the wide sea where the water is blu...
# 3  it was beautiful in the country it was summer-...
#
#                         title                  creator  Data size  \
# 0                  ozma of oz         lyman frank baum       9248
# 1  the wonderful wizard of oz         lyman frank baum       5824
# 2          the little mermaid  hans christian andersen      49115
# 3           the ugly duckling  hans christian andersen      18548
#
#                                               Splits  N_Splits  \
# 0  [the, wind, blew, hard, and, joggled, the, wat...      1799
# 1  [the, cyclone, dorothy, lived, in, the, midst,...      1143
# 2  [far, out, in, the, wide, sea, where, the, wat...      9192
# 3  [it, was, beautiful, in, the, country, it, was...      3612
#
#                                                Lemma       TTR     MATTR
# 0  [the, wind, blow, hard, and, joggle, the, wate...  0.293889  0.780685
# 1  [the, cyclone, dorothy, live, in, the, midst, ...  0.327209  0.778592
# 2  [far, out, in, the, wide, sea, where, the, wat...  0.157419  0.791909
# 3  [it, be, beautiful, in, the, country, it, be, ...  0.209856  0.766292
#                    creator  N_Splits     MATTR
# 0         lyman frank baum      1799  0.780685
# 1         lyman frank baum      1143  0.778592
# 2  hans christian andersen      9192  0.791909
# 3  hans christian andersen      3612  0.766292

# %% [markdown]
# # <font color = 'green'> **MATTR for each creator** (average across different volumes for each creator)

# %%
# Clean up creator names
df['creator'] = df['creator'].str.strip().str.lower()

df_creator_ld = df.groupby("creator")['MATTR'].mean().reset_index()
df_creator_ld = df_creator_ld.round(6)

# --- STEP 6: Save and display results ---
df_creator_ld.to_csv('LD_by_creator.csv', index=False)
print("✅ Lexical diversity by creator saved as 'LD_by_creator.csv'!\n")
df_creator_ld
# Out:
# ✅ Lexical diversity by creator saved as 'LD_by_creator.csv'!
#                    creator     MATTR
# 0  hans christian andersen  0.779101
# 1         lyman frank baum  0.779639

# %% [markdown]
# #<font color = 'red'> **Common Core Words for all 2 creators saved in a single .csv file**

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
from collections import Counter

# Download necessary NLTK resources
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')

# Load the dataset 🍎🍎🍎🍎🍎
file_path = "/content/PictureBook_Project_Demo/Data_Frame_Group2/2creators_2books.csv"  # Change to your actual file name/content/pg_5authors_16books.csv
df_ccw = pd.read_csv(file_path)
# Ensure the text column exists
if 'text' not in df_ccw.columns or 'creator' not in df_ccw.columns:
    raise ValueError("CSV file must contain 'text' and 'creator' columns.")

# Combine all text data into one large string
all_text = " ".join(df_ccw['text'].astype(str))

# Tokenize words
words = word_tokenize(all_text.lower())  # Convert to lowercase

# Remove punctuation and stopwords
stop_words = set(stopwords.words('english'))
words = [word for word in words if word.isalpha() and word not in stop_words]  # Keep only words, no numbers/symbols

# Count word frequencies
word_counts = Counter(words)

# Convert to a DataFrame
common_words_df = pd.DataFrame(word_counts.most_common(100), columns=['Word', 'Frequency'])  # Top 100 words

# Save to CSV 🍎🍎🍎🍎🍎
common_words_df.to_csv("2creators_common_core_words.csv", index=False)

print("Common core words extracted and saved as '2creators_common_core_words.csv'!")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# Common core words extracted and saved as '2creators_common_core_words.csv'!
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # <font color = 'sky blue'> **Creating a word cloud** based on Common Core Words(CCW)

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Path to the combined CSV file (not a folder)🍎🍎🍎🍎🍎
input_file = "/content/PictureBook_Project_Demo/Data_Frame_Group2/2creators_common_core_words.csv"

# Read the CSV containing word-frequency pairs
df = pd.read_csv(input_file)

# Convert to dictionary: {'word1': freq1, 'word2': freq2, ...}
word_freq = dict(zip(df['Word'], df['Frequency']))

# Create and generate the word cloud
wc = WordCloud(width=1000, height=500, background_color='white', colormap='tab10')
wc.generate_from_frequencies(word_freq)

# Display the word cloud inline in Colab
plt.figure(figsize=(15, 7))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.title("WordCloud from All 2 Creators", fontsize=20)
plt.show()
